# %% [markdown]
# #### Ecualización del histograma

# %%
import cv2 as cv
import numpy as np
from matplotlib import pyplot as plt

# %%
img_gray = cv.imread("/Users/miguelcamargorojas/Documents/UP/PDI - Ene-may24/images/baboon.jpg", 0)

# %%
plt.imshow(img_gray, "gray")
plt.show()

# %%
hist_orig = cv.calcHist([img_gray], [0], None, [256], (0, 256))

# %%
plt.plot(hist_orig)
plt.title("Histograma de la img orig.")
plt.show()

# %%
img_eq = cv.equalizeHist(img_gray)

# %%
plt.imshow(np.hstack((img_gray, img_eq)), "gray")
plt.show()

# %% [markdown]
# #### Eq. en img. a color

# %%
img_color = cv.imread("/Users/miguelcamargorojas/Documents/UP/PDI - Ene-may24/images/baboon.jpg")[:, :, ::-1]

# %%
plt.imshow(img_color)
plt.show()

# %%
# Ecualizar todos los canales

r, g, b = cv.split(img_color)
r_eq = cv.equalizeHist(r)
g_eq = cv.equalizeHist(g)
b_eq = cv.equalizeHist(b)
img_color_eq = cv.merge((r_eq, g_eq, b_eq))

# %%
plt.imshow(np.hstack((img_color, img_color_eq)))
plt.show()

# %%
cv.equalizeHist(img_color)
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 cv.equalizeHist(img_color)
#
# error: OpenCV(4.8.1) /Users/xperience/GHA-OpenCV-Python/_work/opencv-python/opencv-python/opencv/modules/imgproc/src/histogram.cpp:3440: error: (-215:Assertion failed) _src.type() == CV_8UC1 in function 'equalizeHist'

# %%
cv.COLOR_RGB2YCrCb
# Out:
# 37

# %%
# YCbCr
# Origen RGB destino es YCbCr
img_color_ycrcb = cv.cvtColor(img_color, cv.COLOR_RGB2YCrCb)

# %%
img_color_ycrcb.shape
# Out:
# (512, 512, 3)

# %%
plt.imshow(img_color_ycrcb)
plt.show()

# %%
y, cr, cb = cv.split(img_color_ycrcb)

# %%
plt.imshow(y, "gray")

# %%
y_eq = cv.equalizeHist(y)

# %%
img_color_ycrcb_eq = cv.merge((y_eq, cr, cb))

# %%
plt.imshow(img_color_ycrcb_eq)

# %%
img_color_rgb_eq = cv.cvtColor(img_color_ycrcb_eq, cv.COLOR_YCrCb2RGB)

# %%
plt.imshow(img_color_rgb_eq)
plt.show()
