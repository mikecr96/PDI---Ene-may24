# %%
import cv2 as cv
import numpy as np
from matplotlib import pyplot as plt

# %%
imagen = cv.imread("/Users/miguelcamargorojas/Documents/UP/PDI - Ene-may24/images/gorra_diablos.png", 0)

# %%
imagen.shape
# Out:
# (640, 640)

# %%
plt.imshow(imagen, 'gray')

# %%
# s = L-1-r
# s = 256 - 1 - r
# s = 255 - r
imagen_neg = 255 - imagen

# %%
plt.imshow(imagen_neg, cmap='gray')

# %%
for n, i in enumerate(range(10, 21)):
    print(n, i)
# Out:
# 0 10
# 1 11
# 2 12
# 3 13
# 4 14
# 5 15
# 6 16
# 7 17
# 8 18
# 9 19
# 10 20

# %%
#NOT BIT A BIT

plt.imshow(np.bitwise_not(imagen), cmap="gray")
