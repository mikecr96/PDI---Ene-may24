# %%
# %pip install opencv-python
# Out:
# ...
#
# [notice] A new release of pip is available: 23.2.1 -> 24.0
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
import cv2 as cv

# %%
PI = 3.14151926

# %%
PI
# Out:
# 3.14151926

# %%
PI = "hola"

# %%
PI
# Out:
# 'hola'

# %%
cv.IMREAD_UNCHANGED
# Out:
# -1

# %%
imagen1 = cv.imread("/Users/miguelcamargorojas/Documents/UP/PDI - Ene-may24/images/aloeL.jpg", cv.IMREAD_UNCHANGED)

# %%
type(imagen1)
# Out:
# numpy.ndarray

# %%
r"C:\User\Mike"
# Out:
# 'C:\\User\\Mike'

# %%
"\\"
# Out:
# '\\'

# %%
imagen1.shape
# Out:
# (1110, 1282, 3)

# %%
# !pwd
# Out:
# /Users/miguelcamargorojas/Documents/UP/PDI - Ene-may24/Semana3

# %%
imagen1[0, 0, 0]
# Out:
# 142

# %%
# cv.imshow("Imagen 1", imagen1)

# %%
# %pip install matplotlib
# Out:
# ...
#
# [notice] A new release of pip is available: 23.2.1 -> 24.0
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
from matplotlib import pyplot as plt

# %%
plt.imshow(imagen1)
plt.title("IMAGEN 1")
# Out:
# Text(0.5, 1.0, 'IMAGEN 1')

# %%
placa = cv.imread("board.jpg")[:, :, ::-1]
# placa = placa[:, :, ::-1]
# Out:
# [ WARN:0@1.948] global loadsave.cpp:248 findDecoder imread_('board.jpg'): can't open/read file: check file path/integrity
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 placa = cv.imread("board.jpg")[:, :, ::-1]
#       2 # placa = placa[:, :, ::-1]
#
# TypeError: 'NoneType' object is not subscriptable

# %%
type(placa)

# %%
placa.shape

# %%
# OpenCV -> BGR
# plt    -> RGB

# %%
plt.imshow(placa[:100, :100, 2], cmap="gray")

# %%
placa.dtype

# %%
imagen1.shape
# Out:
# (1110, 1282, 3)

# %%
plt.imshow(imagen1[:, :, 0], cmap="gray")

# %%
# Apagar canales

# Prendido el R, apago GB
temp = imagen1.copy()
temp[:, :, :2] = 0

# %%
# Prendido el G, apago RB
temp = imagen1.copy()
temp[:, :, (0, 2)] = 0

# %%
temp.shape
# Out:
# (1110, 1282, 3)

# %%
plt.imshow(temp[:, :, ::-1])
